# %%
import pandas as pd

# %%
import datasets

# %%
from pathlib import Path
import os

# %%
data = pd.read_csv("Raw_test_data.csv" , index_col=0)

# %%
data
# Out:
#                      type           created_at  \
# id
# 2.489769e+09  IssuesEvent  2015-01-01 19:10:07
# 2.489781e+09  IssuesEvent  2015-01-01 19:35:13
# 2.490036e+09  IssuesEvent  2015-01-02 05:09:39
# 2.490330e+09  IssuesEvent  2015-01-02 13:12:17
# 2.490330e+09  IssuesEvent  2015-01-02 13:12:47
# ...                   ...                  ...
# 2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                         repo  \
# id
# 2.489769e+09             travi/php-framework
# 2.489781e+09             travi/php-framework
# 2.490036e+09           affektive/digiquatics
# 2.490330e+09              bkimminich/z85-cli
# 2.490330e+09              bkimminich/z85-cli
# ...                                      ...
# 2.297185e+10     LmeSzinc/AzurLaneAutoScript
# 2.297200e+10  mrlesmithjr/ansible-manage-lvm
# 2.297205e+10            wang-xinyu/tensorrtx
# 2.297205e+10            wang-xinyu/tensorrtx
# 2.297296e+10                        jo3-l/yc
#
#                                                        repo_url  action  \
# id
# 2.489769e+09   https://api.github.com/repos/travi/php-framework  closed
# 2.489781e+09   https://api.github.com/repos/travi/php-framework  opened
# 2.490036e+09  https://api.github.com/repos/affektive/digiqua...  closed
# 2.490330e+09    https://api.github.com/repos/bkimminich/z85-cli  opened
# 2.490330e+09    https://api.github.com/repos/bkimminich/z85-cli  closed
# ...                                                         ...     ...
# 2.297185e+10  https://api.github.com/repos/LmeSzinc/AzurLane...  closed
# 2.297200e+10  https://api.github.com/repos/mrlesmithjr/ansib...  closed
# 2.297205e+10  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 2.297205e+10  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 2.297296e+10              https://api.github.com/repos/jo3-l/yc  closed
#
#                                                           title  \
# id
# 2.489769e+09  don't look in min directory when bower depende...
# 2.489781e+09               look for .min file in dist directory
# 2.490036e+09                   remove slide inspection jbuilder
# 2.490330e+09                      Test ticket from Code Climate
# 2.490330e+09                      Test ticket from Code Climate
# ...                                                         ...
# 2.297185e+10                                    增加每日主线困难图出击次数选择
# 2.297200e+10  Need more condition: If disk is not in lvm for...
# 2.297205e+10                                 lenet5 make failed
# 2.297205e+10  Low landmark accuracy for retinaface (mnet) af...
# 2.297296e+10                      bro make a better repo name 💀
#
#                                            labels  \
# id
# 2.489769e+09  design-change enhancement tech-debt
# 2.489781e+09                enhancement tech-debt
# 2.490036e+09                            tech debt
# 2.490330e+09           0 - Backlog technical debt
# 2.490330e+09           0 - Backlog technical debt
# ...                                           ...
# 2.297185e+10                              wontfix
# 2.297200e+10                              wontfix
# 2.297205e+10                              wontfix
# 2.297205e+10                              wontfix
# 2.297296e+10                              wontfix
#
#                                                            body Status_test
# id
# 2.489769e+09                       look for `.min` file instead      NOT_TD
# 2.489781e+09                            as an extension of #78       NOT_TD
# 2.490036e+09                                                NaN      NOT_TD
# 2.490330e+09                                                NaN      NOT_TD
# 2.490330e+09  \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      NOT_TD
# ...                                                         ...         ...
# 2.297185e+10  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      NOT_TD
# 2.297200e+10  [root@localhost ~]# lsblk \r\nNAME            ...      NOT_TD
# 2.297205e+10  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      NOT_TD
# 2.297205e+10  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      NOT_TD
# 2.297296e+10                 like what does yc stand for???????      NOT_TD
#
# [667681 rows x 9 columns]

# %%
data["Status_test"].value_counts()
# Out:
# Status_test
# NOT_TD    664260
# TD          3421
# Name: count, dtype: int64

# %%
data["label"] = (data["Status_test"] == "TD").astype(int)

# %%
data
# Out:
#                      type           created_at  \
# id
# 2.489769e+09  IssuesEvent  2015-01-01 19:10:07
# 2.489781e+09  IssuesEvent  2015-01-01 19:35:13
# 2.490036e+09  IssuesEvent  2015-01-02 05:09:39
# 2.490330e+09  IssuesEvent  2015-01-02 13:12:17
# 2.490330e+09  IssuesEvent  2015-01-02 13:12:47
# ...                   ...                  ...
# 2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                         repo  \
# id
# 2.489769e+09             travi/php-framework
# 2.489781e+09             travi/php-framework
# 2.490036e+09           affektive/digiquatics
# 2.490330e+09              bkimminich/z85-cli
# 2.490330e+09              bkimminich/z85-cli
# ...                                      ...
# 2.297185e+10     LmeSzinc/AzurLaneAutoScript
# 2.297200e+10  mrlesmithjr/ansible-manage-lvm
# 2.297205e+10            wang-xinyu/tensorrtx
# 2.297205e+10            wang-xinyu/tensorrtx
# 2.297296e+10                        jo3-l/yc
#
#                                                        repo_url  action  \
# id
# 2.489769e+09   https://api.github.com/repos/travi/php-framework  closed
# 2.489781e+09   https://api.github.com/repos/travi/php-framework  opened
# 2.490036e+09  https://api.github.com/repos/affektive/digiqua...  closed
# 2.490330e+09    https://api.github.com/repos/bkimminich/z85-cli  opened
# 2.490330e+09    https://api.github.com/repos/bkimminich/z85-cli  closed
# ...                                                         ...     ...
# 2.297185e+10  https://api.github.com/repos/LmeSzinc/AzurLane...  closed
# 2.297200e+10  https://api.github.com/repos/mrlesmithjr/ansib...  closed
# 2.297205e+10  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 2.297205e+10  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 2.297296e+10              https://api.github.com/repos/jo3-l/yc  closed
#
#                                                           title  \
# id
# 2.489769e+09  don't look in min directory when bower depende...
# 2.489781e+09               look for .min file in dist directory
# 2.490036e+09                   remove slide inspection jbuilder
# 2.490330e+09                      Test ticket from Code Climate
# 2.490330e+09                      Test ticket from Code Climate
# ...                                                         ...
# 2.297185e+10                                    增加每日主线困难图出击次数选择
# 2.297200e+10  Need more condition: If disk is not in lvm for...
# 2.297205e+10                                 lenet5 make failed
# 2.297205e+10  Low landmark accuracy for retinaface (mnet) af...
# 2.297296e+10                      bro make a better repo name 💀
#
#                                            labels  \
# id
# 2.489769e+09  design-change enhancement tech-debt
# 2.489781e+09                enhancement tech-debt
# 2.490036e+09                            tech debt
# 2.490330e+09           0 - Backlog technical debt
# 2.490330e+09           0 - Backlog technical debt
# ...                                           ...
# 2.297185e+10                              wontfix
# 2.297200e+10                              wontfix
# 2.297205e+10                              wontfix
# 2.297205e+10                              wontfix
# 2.297296e+10                              wontfix
#
#                                                            body Status_test  \
# id
# 2.489769e+09                       look for `.min` file instead      NOT_TD
# 2.489781e+09                            as an extension of #78       NOT_TD
# 2.490036e+09                                                NaN      NOT_TD
# 2.490330e+09                                                NaN      NOT_TD
# 2.490330e+09  \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      NOT_TD
# ...                                                         ...         ...
# 2.297185e+10  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      NOT_TD
# 2.297200e+10  [root@localhost ~]# lsblk \r\nNAME            ...      NOT_TD
# 2.297205e+10  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      NOT_TD
# 2.297205e+10  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      NOT_TD
# 2.297296e+10                 like what does yc stand for???????      NOT_TD
#
#               label
# id
# 2.489769e+09      0
# 2.489781e+09      0
# 2.490036e+09      0
# 2.490330e+09      0
# 2.490330e+09      0
# ...             ...
# 2.297185e+10      0
# 2.297200e+10      0
# 2.297205e+10      0
# 2.297205e+10      0
# 2.297296e+10      0
#
# [667681 rows x 10 columns]

# %%
df = data.drop_duplicates(subset=['body'], keep='last')

# %%
df.dropna(inplace=True)
# Out:
# /tmp/ipykernel_3025819/1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df
# Out:
#                      type           created_at  \
# id
# 2.489769e+09  IssuesEvent  2015-01-01 19:10:07
# 2.489781e+09  IssuesEvent  2015-01-01 19:35:13
# 2.490330e+09  IssuesEvent  2015-01-02 13:12:47
# 2.490610e+09  IssuesEvent  2015-01-02 17:29:17
# 2.490610e+09  IssuesEvent  2015-01-02 17:29:18
# ...                   ...                  ...
# 2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                         repo  \
# id
# 2.489769e+09             travi/php-framework
# 2.489781e+09             travi/php-framework
# 2.490330e+09              bkimminich/z85-cli
# 2.490610e+09      FineUploader/fine-uploader
# 2.490610e+09      FineUploader/fine-uploader
# ...                                      ...
# 2.297185e+10     LmeSzinc/AzurLaneAutoScript
# 2.297200e+10  mrlesmithjr/ansible-manage-lvm
# 2.297205e+10            wang-xinyu/tensorrtx
# 2.297205e+10            wang-xinyu/tensorrtx
# 2.297296e+10                        jo3-l/yc
#
#                                                        repo_url  action  \
# id
# 2.489769e+09   https://api.github.com/repos/travi/php-framework  closed
# 2.489781e+09   https://api.github.com/repos/travi/php-framework  opened
# 2.490330e+09    https://api.github.com/repos/bkimminich/z85-cli  closed
# 2.490610e+09  https://api.github.com/repos/FineUploader/fine...  closed
# 2.490610e+09  https://api.github.com/repos/FineUploader/fine...  closed
# ...                                                         ...     ...
# 2.297185e+10  https://api.github.com/repos/LmeSzinc/AzurLane...  closed
# 2.297200e+10  https://api.github.com/repos/mrlesmithjr/ansib...  closed
# 2.297205e+10  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 2.297205e+10  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 2.297296e+10              https://api.github.com/repos/jo3-l/yc  closed
#
#                                                           title  \
# id
# 2.489769e+09  don't look in min directory when bower depende...
# 2.489781e+09               look for .min file in dist directory
# 2.490330e+09                      Test ticket from Code Climate
# 2.490610e+09                 5 - Get build script under control
# 2.490610e+09                   5 - Enforce code styles via JSCS
# ...                                                         ...
# 2.297185e+10                                    增加每日主线困难图出击次数选择
# 2.297200e+10  Need more condition: If disk is not in lvm for...
# 2.297205e+10                                 lenet5 make failed
# 2.297205e+10  Low landmark accuracy for retinaface (mnet) af...
# 2.297296e+10                      bro make a better repo name 💀
#
#                                            labels  \
# id
# 2.489769e+09  design-change enhancement tech-debt
# 2.489781e+09                enhancement tech-debt
# 2.490330e+09           0 - Backlog technical debt
# 2.490610e+09        5 - Done build technical debt
# 2.490610e+09              5 - Done technical debt
# ...                                           ...
# 2.297185e+10                              wontfix
# 2.297200e+10                              wontfix
# 2.297205e+10                              wontfix
# 2.297205e+10                              wontfix
# 2.297296e+10                              wontfix
#
#                                                            body Status_test  \
# id
# 2.489769e+09                       look for `.min` file instead      NOT_TD
# 2.489781e+09                            as an extension of #78       NOT_TD
# 2.490330e+09  \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      NOT_TD
# 2.490610e+09  Our grunt script is out of control.  It's curr...      NOT_TD
# 2.490610e+09  JSHint is dropping style-related support it se...      NOT_TD
# ...                                                         ...         ...
# 2.297185e+10  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      NOT_TD
# 2.297200e+10  [root@localhost ~]# lsblk \r\nNAME            ...      NOT_TD
# 2.297205e+10  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      NOT_TD
# 2.297205e+10  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      NOT_TD
# 2.297296e+10                 like what does yc stand for???????      NOT_TD
#
#               label
# id
# 2.489769e+09      0
# 2.489781e+09      0
# 2.490330e+09      0
# 2.490610e+09      0
# 2.490610e+09      0
# ...             ...
# 2.297185e+10      0
# 2.297200e+10      0
# 2.297205e+10      0
# 2.297205e+10      0
# 2.297296e+10      0
#
# [470605 rows x 10 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                   id         type           created_at  \
# 0       2.489769e+09  IssuesEvent  2015-01-01 19:10:07
# 1       2.489781e+09  IssuesEvent  2015-01-01 19:35:13
# 2       2.490330e+09  IssuesEvent  2015-01-02 13:12:47
# 3       2.490610e+09  IssuesEvent  2015-01-02 17:29:17
# 4       2.490610e+09  IssuesEvent  2015-01-02 17:29:18
# ...              ...          ...                  ...
# 470600  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 470601  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 470602  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 470603  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 470604  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                   repo  \
# 0                  travi/php-framework
# 1                  travi/php-framework
# 2                   bkimminich/z85-cli
# 3           FineUploader/fine-uploader
# 4           FineUploader/fine-uploader
# ...                                ...
# 470600     LmeSzinc/AzurLaneAutoScript
# 470601  mrlesmithjr/ansible-manage-lvm
# 470602            wang-xinyu/tensorrtx
# 470603            wang-xinyu/tensorrtx
# 470604                        jo3-l/yc
#
#                                                  repo_url  action  \
# 0        https://api.github.com/repos/travi/php-framework  closed
# 1        https://api.github.com/repos/travi/php-framework  opened
# 2         https://api.github.com/repos/bkimminich/z85-cli  closed
# 3       https://api.github.com/repos/FineUploader/fine...  closed
# 4       https://api.github.com/repos/FineUploader/fine...  closed
# ...                                                   ...     ...
# 470600  https://api.github.com/repos/LmeSzinc/AzurLane...  closed
# 470601  https://api.github.com/repos/mrlesmithjr/ansib...  closed
# 470602  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 470603  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 470604              https://api.github.com/repos/jo3-l/yc  closed
#
#                                                     title  \
# 0       don't look in min directory when bower depende...
# 1                    look for .min file in dist directory
# 2                           Test ticket from Code Climate
# 3                      5 - Get build script under control
# 4                        5 - Enforce code styles via JSCS
# ...                                                   ...
# 470600                                    增加每日主线困难图出击次数选择
# 470601  Need more condition: If disk is not in lvm for...
# 470602                                 lenet5 make failed
# 470603  Low landmark accuracy for retinaface (mnet) af...
# 470604                      bro make a better repo name 💀
#
#                                      labels  \
# 0       design-change enhancement tech-debt
# 1                     enhancement tech-debt
# 2                0 - Backlog technical debt
# 3             5 - Done build technical debt
# 4                   5 - Done technical debt
# ...                                     ...
# 470600                              wontfix
# 470601                              wontfix
# 470602                              wontfix
# 470603                              wontfix
# 470604                              wontfix
#
#                                                      body Status_test  label
# 0                            look for `.min` file instead      NOT_TD      0
# 1                                 as an extension of #78       NOT_TD      0
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      NOT_TD      0
# 3       Our grunt script is out of control.  It's curr...      NOT_TD      0
# 4       JSHint is dropping style-related support it se...      NOT_TD      0
# ...                                                   ...         ...    ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      NOT_TD      0
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...      NOT_TD      0
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      NOT_TD      0
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      NOT_TD      0
# 470604                 like what does yc stand for???????      NOT_TD      0
#
# [470605 rows x 11 columns]

# %%
df["label"].value_counts()
# Out:
# label
# 0    468116
# 1      2489
# Name: count, dtype: int64

# %%
df["text"] = df["body"]
# Out:
# /tmp/ipykernel_3025819/126701239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text"] = df["body"]

# %%
df
# Out:
#                   id         type           created_at  \
# 0       2.489769e+09  IssuesEvent  2015-01-01 19:10:07
# 1       2.489781e+09  IssuesEvent  2015-01-01 19:35:13
# 2       2.490330e+09  IssuesEvent  2015-01-02 13:12:47
# 3       2.490610e+09  IssuesEvent  2015-01-02 17:29:17
# 4       2.490610e+09  IssuesEvent  2015-01-02 17:29:18
# ...              ...          ...                  ...
# 470600  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 470601  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 470602  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 470603  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 470604  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                   repo  \
# 0                  travi/php-framework
# 1                  travi/php-framework
# 2                   bkimminich/z85-cli
# 3           FineUploader/fine-uploader
# 4           FineUploader/fine-uploader
# ...                                ...
# 470600     LmeSzinc/AzurLaneAutoScript
# 470601  mrlesmithjr/ansible-manage-lvm
# 470602            wang-xinyu/tensorrtx
# 470603            wang-xinyu/tensorrtx
# 470604                        jo3-l/yc
#
#                                                  repo_url  action  \
# 0        https://api.github.com/repos/travi/php-framework  closed
# 1        https://api.github.com/repos/travi/php-framework  opened
# 2         https://api.github.com/repos/bkimminich/z85-cli  closed
# 3       https://api.github.com/repos/FineUploader/fine...  closed
# 4       https://api.github.com/repos/FineUploader/fine...  closed
# ...                                                   ...     ...
# 470600  https://api.github.com/repos/LmeSzinc/AzurLane...  closed
# 470601  https://api.github.com/repos/mrlesmithjr/ansib...  closed
# 470602  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 470603  https://api.github.com/repos/wang-xinyu/tensorrtx  closed
# 470604              https://api.github.com/repos/jo3-l/yc  closed
#
#                                                     title  \
# 0       don't look in min directory when bower depende...
# 1                    look for .min file in dist directory
# 2                           Test ticket from Code Climate
# 3                      5 - Get build script under control
# 4                        5 - Enforce code styles via JSCS
# ...                                                   ...
# 470600                                    增加每日主线困难图出击次数选择
# 470601  Need more condition: If disk is not in lvm for...
# 470602                                 lenet5 make failed
# 470603  Low landmark accuracy for retinaface (mnet) af...
# 470604                      bro make a better repo name 💀
#
#                                      labels  \
# 0       design-change enhancement tech-debt
# 1                     enhancement tech-debt
# 2                0 - Backlog technical debt
# 3             5 - Done build technical debt
# 4                   5 - Done technical debt
# ...                                     ...
# 470600                              wontfix
# 470601                              wontfix
# 470602                              wontfix
# 470603                              wontfix
# 470604                              wontfix
#
#                                                      body Status_test  label  \
# 0                            look for `.min` file instead      NOT_TD      0
# 1                                 as an extension of #78       NOT_TD      0
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      NOT_TD      0
# 3       Our grunt script is out of control.  It's curr...      NOT_TD      0
# 4       JSHint is dropping style-related support it se...      NOT_TD      0
# ...                                                   ...         ...    ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      NOT_TD      0
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...      NOT_TD      0
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      NOT_TD      0
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      NOT_TD      0
# 470604                 like what does yc stand for???????      NOT_TD      0
#
#                                                      text
# 0                            look for `.min` file instead
# 1                                 as an extension of #78
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...
# 3       Our grunt script is out of control.  It's curr...
# 4       JSHint is dropping style-related support it se...
# ...                                                   ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....
# 470604                 like what does yc stand for???????
#
# [470605 rows x 12 columns]

# %%
df1 = df[["text" , "label" , "Status_test"]]

# %%
df1
# Out:
#                                                      text  label Status_test
# 0                            look for `.min` file instead      0      NOT_TD
# 1                                 as an extension of #78       0      NOT_TD
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      0      NOT_TD
# 3       Our grunt script is out of control.  It's curr...      0      NOT_TD
# 4       JSHint is dropping style-related support it se...      0      NOT_TD
# ...                                                   ...    ...         ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      0      NOT_TD
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...      0      NOT_TD
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      0      NOT_TD
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      0      NOT_TD
# 470604                 like what does yc stand for???????      0      NOT_TD
#
# [470605 rows x 3 columns]

# %%
df1.to_csv("subsetTD_dataset.csv")

# %%
df1
# Out:
#                                                      text  label Status_test
# 0                            look for `.min` file instead      0      NOT_TD
# 1                                 as an extension of #78       0      NOT_TD
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      0      NOT_TD
# 3       Our grunt script is out of control.  It's curr...      0      NOT_TD
# 4       JSHint is dropping style-related support it se...      0      NOT_TD
# ...                                                   ...    ...         ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      0      NOT_TD
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...      0      NOT_TD
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      0      NOT_TD
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      0      NOT_TD
# 470604                 like what does yc stand for???????      0      NOT_TD
#
# [470605 rows x 3 columns]

# %%
import re
from string import punctuation
import numpy as np

# %%
df1["text_str"] = df1['text'].astype(str)
# Out:
# /tmp/ipykernel_3025819/423982908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["text_str"] = df1['text'].astype(str)

# %%
df1
# Out:
#                                                      text  label Status_test  \
# 0                            look for `.min` file instead      0      NOT_TD
# 1                                 as an extension of #78       0      NOT_TD
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      0      NOT_TD
# 3       Our grunt script is out of control.  It's curr...      0      NOT_TD
# 4       JSHint is dropping style-related support it se...      0      NOT_TD
# ...                                                   ...    ...         ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      0      NOT_TD
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...      0      NOT_TD
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      0      NOT_TD
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      0      NOT_TD
# 470604                 like what does yc stand for???????      0      NOT_TD
#
#                                                  text_str
# 0                            look for `.min` file instead
# 1                                 as an extension of #78
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...
# 3       Our grunt script is out of control.  It's curr...
# 4       JSHint is dropping style-related support it se...
# ...                                                   ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....
# 470604                 like what does yc stand for???????
#
# [470605 rows x 4 columns]

# %%
def preprocess_text(text):
    text = text.lower()  # Lowercase text
    text = re.sub(f"[{re.escape(punctuation)}]", "", text)  # Remove punctuation
    text = " ".join(text.split())  # Remove extra spaces, tabs, and new lines
    text = re.sub(r"https?://\S+", "", text)
    return text

df1["text_clean"] = df1["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_3025819/2112481758.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["text_clean"] = df1["text_str"].map(preprocess_text)

# %%
df1
# Out:
#                                                      text  label Status_test  \
# 0                            look for `.min` file instead      0      NOT_TD
# 1                                 as an extension of #78       0      NOT_TD
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...      0      NOT_TD
# 3       Our grunt script is out of control.  It's curr...      0      NOT_TD
# 4       JSHint is dropping style-related support it se...      0      NOT_TD
# ...                                                   ...    ...         ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...      0      NOT_TD
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...      0      NOT_TD
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...      0      NOT_TD
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....      0      NOT_TD
# 470604                 like what does yc stand for???????      0      NOT_TD
#
#                                                  text_str  \
# 0                            look for `.min` file instead
# 1                                 as an extension of #78
# 2       \r\n\r\n<bountysource-plugin>\r\n\r\n---\r\nWa...
# 3       Our grunt script is out of control.  It's curr...
# 4       JSHint is dropping style-related support it se...
# ...                                                   ...
# 470600  ### 你的功能请求是否与问题有关？\n\n希望可以为每日任务 > 困难图 增加次数选择功能...
# 470601  [root@localhost ~]# lsblk \r\nNAME            ...
# 470602  ## Env\r\n\r\n- GPU, RTX1060\r\n- OS,  Ubuntu1...
# 470603  ## Env\r\n\r\n- GPU, 1080ti\r\n- OS, Ubuntu18....
# 470604                 like what does yc stand for???????
#
#                                                text_clean
# 0                               look for min file instead
# 1                                   as an extension of 78
# 2       bountysourceplugin want to back this issue pla...
# 3       our grunt script is out of control its current...
# 4       jshint is dropping stylerelated support it see...
# ...                                                   ...
# 470600  你的功能请求是否与问题有关？ 希望可以为每日任务 困难图 增加次数选择功能。目前我的解决办法...
# 470601  rootlocalhost lsblk name majmin rm size ro typ...
# 470602  env gpu rtx1060 os ubuntu1804 docker cuda vers...
# 470603  env gpu 1080ti os ubuntu1804 cuda version114 t...
# 470604                        like what does yc stand for
#
# [470605 rows x 5 columns]

# %%
df2 = df1[["text_clean" , "label"]]

# %%
df2
# Out:
#                                                text_clean  label
# 0                               look for min file instead      0
# 1                                   as an extension of 78      0
# 2       bountysourceplugin want to back this issue pla...      0
# 3       our grunt script is out of control its current...      0
# 4       jshint is dropping stylerelated support it see...      0
# ...                                                   ...    ...
# 470600  你的功能请求是否与问题有关？ 希望可以为每日任务 困难图 增加次数选择功能。目前我的解决办法...      0
# 470601  rootlocalhost lsblk name majmin rm size ro typ...      0
# 470602  env gpu rtx1060 os ubuntu1804 docker cuda vers...      0
# 470603  env gpu 1080ti os ubuntu1804 cuda version114 t...      0
# 470604                        like what does yc stand for      0
#
# [470605 rows x 2 columns]

# %%
df2.to_csv("TD_dataset_clean.csv")

# %%
import datasets
from datasets import load_dataset, Dataset, DatasetDict

# %%
df2 = pd.read_csv("TD_dataset_clean.csv", index_col=0)
df2
# Out:
#                                                text_clean  label
# 0                               look for min file instead      0
# 1                                   as an extension of 78      0
# 2       bountysourceplugin want to back this issue pla...      0
# 3       our grunt script is out of control its current...      0
# 4       jshint is dropping stylerelated support it see...      0
# ...                                                   ...    ...
# 470600  你的功能请求是否与问题有关？ 希望可以为每日任务 困难图 增加次数选择功能。目前我的解决办法...      0
# 470601  rootlocalhost lsblk name majmin rm size ro typ...      0
# 470602  env gpu rtx1060 os ubuntu1804 docker cuda vers...      0
# 470603  env gpu 1080ti os ubuntu1804 cuda version114 t...      0
# 470604                        like what does yc stand for      0
#
# [470605 rows x 2 columns]

# %%
df2.dropna(inplace=True)

# %%
df2.reset_index(inplace=True)
