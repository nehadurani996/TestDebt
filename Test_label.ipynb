# %%
import pandas as pd

# %%
import datasets

# %%
from pathlib import Path
import os

# %%
data = pd.read_csv("Full_Dataset.csv" , index_col=0)

# %%
data
# Out:
#                   id         type           created_at  \
# 0       2.489769e+09  IssuesEvent  2015-01-01 19:10:07
# 1       2.489781e+09  IssuesEvent  2015-01-01 19:35:13
# 2       2.490036e+09  IssuesEvent  2015-01-02 05:09:39
# 3       2.490330e+09  IssuesEvent  2015-01-02 13:12:17
# 4       2.490330e+09  IssuesEvent  2015-01-02 13:12:47
# ...              ...          ...                  ...
# 667676  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 667677  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 667678  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 667679  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 667680  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                   repo  \
# 0                  travi/php-framework
# 1                  travi/php-framework
# 2                affektive/digiquatics
# 3                   bkimminich/z85-cli
# 4                   bkimminich/z85-cli
# ...                                ...
# ...

# %%
data = data.drop('class', axis=1)

# %%
data
# Out:
#                   id         type           created_at  \
# 0       2.489769e+09  IssuesEvent  2015-01-01 19:10:07
# 1       2.489781e+09  IssuesEvent  2015-01-01 19:35:13
# 2       2.490036e+09  IssuesEvent  2015-01-02 05:09:39
# 3       2.490330e+09  IssuesEvent  2015-01-02 13:12:17
# 4       2.490330e+09  IssuesEvent  2015-01-02 13:12:47
# ...              ...          ...                  ...
# 667676  2.297185e+10  IssuesEvent  2022-07-20 04:27:22
# 667677  2.297200e+10  IssuesEvent  2022-07-20 04:40:38
# 667678  2.297205e+10  IssuesEvent  2022-07-20 04:45:39
# 667679  2.297205e+10  IssuesEvent  2022-07-20 04:45:40
# 667680  2.297296e+10  IssuesEvent  2022-07-20 06:04:12
#
#                                   repo  \
# 0                  travi/php-framework
# 1                  travi/php-framework
# 2                affektive/digiquatics
# 3                   bkimminich/z85-cli
# 4                   bkimminich/z85-cli
# ...                                ...
# ...

# %%
def label_td(row):
    if isinstance(row['labels'], str) and 'test' in row['labels'].lower():
        return 'TD'
    else:
        return 'NOT_TD'

# %%
data['Status_test'] = data.apply(label_td, axis=1)

# %%
data.to_csv('Raw_test_data.csv', index=False)
