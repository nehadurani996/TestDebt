# %%
import pandas as pd
import sys
sys.path.append("scripts_shared")
from preprocess_text import preprocess_text

# %%
test = pd.read_csv("test_label_with_td.csv", index_col=0)
not_test = pd.read_csv("not_test_label_with_td.csv", index_col=0)

# %%
contains_stale = not_test['labels'].str.contains("stale", case=False, na=False)
not_test= not_test[~contains_stale].reset_index(drop=True)
not_test.reset_index(drop=True, inplace=True)
not_test
# Out:
#                  id         type           created_at  \
# 0      2.729966e+10  IssuesEvent  2023-02-24 00:07:05
# 1      2.729967e+10  IssuesEvent  2023-02-24 00:08:15
# 2      2.729967e+10  IssuesEvent  2023-02-24 00:08:19
# 3      2.729967e+10  IssuesEvent  2023-02-24 00:08:22
# 4      2.729967e+10  IssuesEvent  2023-02-24 00:08:24
# ...             ...          ...                  ...
# 18360  2.393340e+10  IssuesEvent  2022-09-10 22:11:28
# 18361  2.393345e+10  IssuesEvent  2022-09-10 22:22:14
# 18362  2.393346e+10  IssuesEvent  2022-09-10 22:23:14
# 18363  2.393367e+10  IssuesEvent  2022-09-10 23:15:34
# 18364  2.393375e+10  IssuesEvent  2022-09-10 23:36:47
#
#                                     repo  \
# 0                kylecorry31/Trail-Sense
# 1      ntlarissa/devops-capstone-project
# 2      ntlarissa/devops-capstone-project
# 3      ntlarissa/devops-capstone-project
# 4      ntlarissa/devops-capstone-project
# ...                                  ...
# 18360      tameka1222/lab-agile-planning
# 18361      tameka1222/lab-agile-planning
# 18362                TonyLB/maketheworld
# 18363       Omoella16/lab-agile-planning
# 18364       Omoella16/lab-agile-planning
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/kylecorry31/Trail...  opened
# 1      https://api.github.com/repos/ntlarissa/devops-...  closed
# 2      https://api.github.com/repos/ntlarissa/devops-...  closed
# 3      https://api.github.com/repos/ntlarissa/devops-...  closed
# 4      https://api.github.com/repos/ntlarissa/devops-...  closed
# ...                                                  ...     ...
# 18360  https://api.github.com/repos/tameka1222/lab-ag...  closed
# 18361  https://api.github.com/repos/tameka1222/lab-ag...  opened
# 18362   https://api.github.com/repos/TonyLB/maketheworld  closed
# 18363  https://api.github.com/repos/Omoella16/lab-agi...  closed
# 18364  https://api.github.com/repos/Omoella16/lab-agi...  opened
#
#                                                 title                  labels  \
# 0                             Cache preference values            tech-debt p2
# 1                    Update an account in the service          technical debt
# 2                  Delete an account from the service          technical debt
# 3                    List all accounts in the service          technical debt
# 4                  Set up the development environment          technical debt
# ...                                               ...                     ...
# 18360                     Deploy service to the cloud          technical debt
# 18361            Complete Deploy Service to the Cloud          technical debt
# 18362  Add README for character layer in asset lambda  documentation techdebt
# 18363                    Deploy service to the cloud           technical debt
# 18364            complete deploy service to the cloud          technical debt
#
#                                                     body
# 0      - [ ] Make user prefs a singleton\r\n- [ ] Reg...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 18360  **As a** Service Provider\n **I need** the ser...
# 18361  **As a** Service Provider  \n **I need** the s...
# 18362                                                NaN
# 18363  **As a** user\n **I need** the ability to depl...
# 18364  - [ ] database still need to be provisioned\n-...
#
# [18365 rows x 9 columns]

# %%
test[test["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Number or different labels
not_test.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# technical debt                                       4339
# tech debt                                             752
# Technical Debt                                        672
# techdebt                                              641
# tech-debt                                             573
# Technical debt                                        437
# debt                                                  396
# technical-debt                                        279
# Tech Debt                                             208
# enhancement technical debt                             81
# task backlog tech-debt                                 75
# vsa-debt                                               64
# tech_debt                                              58
# T: tech-debt ⚙️                                        53
# Good First Issue Help Wanted Area/Technical Deb...     53
# enhancement tech debt                                  52
# :money_mouth_face: tech debt :warning: P2              48
# design vsa-debt                                        45
# Tech Debt Notify                                       43
# ENTITY techdebt                                        43
# Tech debt                                              42
# :credit_card: technical-debt                           39
# 🔧 Tech Debt                                            38
# tech debt triage                                       37
# kind/tech-debt                                         36
# bug tech-debt                                          35
# techdebt epic                                          34
# enhancement tech-debt                                  34
# Tooling Tech debt                                      32
# type-debt                                              32
# documentation technical debt                           31
# low priority preview tech debt                         30
# Tech Debt dependency update                            30
# good first issue technical debt                        29
# Technology CSP: AWS Technical Debt                     29
# tech-debt no-issue-activity                            29
# type: technical debt                                   29
# Tech Debt Notify QA Review Needed                      29
# bug technical debt                                     29
# documentation techdebt                                 29
# frontend vsa-debt FSR Enhancements PTEMS               28
# type/debt                                              28
# :bank: debt                                            28
# debt team/repo-management                              27
# Technical Debt REST API                                27
# experience tech-debt                                   26
# tech debt Task                                         26
# pipeline tech-debt                                     26
# task tech debt                                         26
# role: dev 🤖 version: 11 package: @carbon/react ...     25

# %%
test[test["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Remove mypy from the dataset
test = test[test["repo"] != "python/mypy"]
test
# Out:
#                id         type           created_at  \
# 0    2.700908e+10  IssuesEvent  2023-02-10 14:05:00
# 1    2.733402e+10  IssuesEvent  2023-02-26 00:56:03
# 2    2.733402e+10  IssuesEvent  2023-02-26 00:56:29
# 3    2.733402e+10  IssuesEvent  2023-02-26 00:56:57
# 4    2.414163e+10  IssuesEvent  2022-09-21 15:14:12
# ..            ...          ...                  ...
# 289  2.444580e+10  IssuesEvent  2022-10-06 17:51:03
# 290  2.444604e+10  IssuesEvent  2022-10-06 18:03:52
# 291  2.745125e+10  IssuesEvent  2023-03-02 17:32:05
# 292  2.436549e+10  IssuesEvent  2022-10-03 14:52:10
# 293  2.392685e+10  IssuesEvent  2022-09-10 00:56:15
#
#                                           repo  \
# 0                         harnettmatt/rankings
# 1                           DataBiosphere/azul
# 2                           DataBiosphere/azul
# 3                           DataBiosphere/azul
# 4    department-of-veterans-affairs/va.gov-cms
# ..                                         ...
# 289           confidential-containers/operator
# 290           confidential-containers/operator
# 291                             saltstack/salt
# 292                    hashicorp/terraform-cdk
# 293                              libhal/libhal
#
#                                               repo_url  action  \
# 0    https://api.github.com/repos/harnettmatt/rankings  closed
# 1      https://api.github.com/repos/DataBiosphere/azul  closed
# 2      https://api.github.com/repos/DataBiosphere/azul  closed
# 3      https://api.github.com/repos/DataBiosphere/azul  closed
# 4    https://api.github.com/repos/department-of-vet...  closed
# ..                                                 ...     ...
# 289  https://api.github.com/repos/confidential-cont...  opened
# 290  https://api.github.com/repos/confidential-cont...  opened
# 291        https://api.github.com/repos/saltstack/salt  closed
# 292  https://api.github.com/repos/hashicorp/terrafo...  opened
# 293         https://api.github.com/repos/libhal/libhal  closed
#
#                                                  title  \
# 0    Make sure integration tests are running with i...
# 1           Cover AnVIL service response in unit tests
# 2    Service `app.repository_controller` should be ...
# 3               Many caches persist between test cases
# 4    Improve friendliness of Behat text pattern mat...
# ..                                                 ...
# 289  Development and CI versions should be kept in ...
# 290                           Document the operator CI
# 291  [TECH DEBT] Add performance test to the test s...
# 292            Re-enable `convertProject.test.ts` test
# 293                      Complete `mock::steady_clock`
#
#                                                 labels  \
# 0                                         testing debt
# 1                     enh demoed debt test orange demo
# 2         bug debt test orange no demo spike:2 service
# 3                 enh debt test orange no demo spike:2
# 4     Technical debt Automated testing ⭐️ Sitewide CMS
# ..                                                 ...
# 289                             testing technical debt
# 290                             testing technical debt
# 291                                auto-test tech-debt
# 292  enhancement testing priority/important-soon de...
# 293                             testing technical debt
#
#                                                   body
# 0    Make sure tests are not interfering with each ...
# 1    https://github.com/DataBiosphere/azul/pull/492...
# 2    https://github.com/DataBiosphere/azul/blob/350...
# 3    ~An example is~ https://github.com/DataBiosphe...
# 4    ## Description\r\n\r\nIn [this commit](https:/...
# ..                                                 ...
# 289  The operator build is supported with a given v...
# 290  The scripts for testing and CI were created in...
# 291  Add performance test to the test suite.\r\n\r\...
# 292  <!--- Please keep this note for the community ...
# 293                                                NaN
#
# [294 rows x 9 columns]

# %%
not_test[not_test["repo"] == "python/mypy"]
# Out:
# Empty DataFrame
# Columns: [id, type, created_at, repo, repo_url, action, title, labels, body]
# Index: []

# %%
# Remove mypy from the dataset
not_test = not_test[not_test["repo"] != "python/mypy"]
not_test
# Out:
#                  id         type           created_at  \
# 0      2.729966e+10  IssuesEvent  2023-02-24 00:07:05
# 1      2.729967e+10  IssuesEvent  2023-02-24 00:08:15
# 2      2.729967e+10  IssuesEvent  2023-02-24 00:08:19
# 3      2.729967e+10  IssuesEvent  2023-02-24 00:08:22
# 4      2.729967e+10  IssuesEvent  2023-02-24 00:08:24
# ...             ...          ...                  ...
# 18360  2.393340e+10  IssuesEvent  2022-09-10 22:11:28
# 18361  2.393345e+10  IssuesEvent  2022-09-10 22:22:14
# 18362  2.393346e+10  IssuesEvent  2022-09-10 22:23:14
# 18363  2.393367e+10  IssuesEvent  2022-09-10 23:15:34
# 18364  2.393375e+10  IssuesEvent  2022-09-10 23:36:47
#
#                                     repo  \
# 0                kylecorry31/Trail-Sense
# 1      ntlarissa/devops-capstone-project
# 2      ntlarissa/devops-capstone-project
# 3      ntlarissa/devops-capstone-project
# 4      ntlarissa/devops-capstone-project
# ...                                  ...
# 18360      tameka1222/lab-agile-planning
# 18361      tameka1222/lab-agile-planning
# 18362                TonyLB/maketheworld
# 18363       Omoella16/lab-agile-planning
# 18364       Omoella16/lab-agile-planning
#
#                                                 repo_url  action  \
# 0      https://api.github.com/repos/kylecorry31/Trail...  opened
# 1      https://api.github.com/repos/ntlarissa/devops-...  closed
# 2      https://api.github.com/repos/ntlarissa/devops-...  closed
# 3      https://api.github.com/repos/ntlarissa/devops-...  closed
# 4      https://api.github.com/repos/ntlarissa/devops-...  closed
# ...                                                  ...     ...
# 18360  https://api.github.com/repos/tameka1222/lab-ag...  closed
# 18361  https://api.github.com/repos/tameka1222/lab-ag...  opened
# 18362   https://api.github.com/repos/TonyLB/maketheworld  closed
# 18363  https://api.github.com/repos/Omoella16/lab-agi...  closed
# 18364  https://api.github.com/repos/Omoella16/lab-agi...  opened
#
#                                                 title                  labels  \
# 0                             Cache preference values            tech-debt p2
# 1                    Update an account in the service          technical debt
# 2                  Delete an account from the service          technical debt
# 3                    List all accounts in the service          technical debt
# 4                  Set up the development environment          technical debt
# ...                                               ...                     ...
# 18360                     Deploy service to the cloud          technical debt
# 18361            Complete Deploy Service to the Cloud          technical debt
# 18362  Add README for character layer in asset lambda  documentation techdebt
# 18363                    Deploy service to the cloud           technical debt
# 18364            complete deploy service to the cloud          technical debt
#
#                                                     body
# 0      - [ ] Make user prefs a singleton\r\n- [ ] Reg...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 18360  **As a** Service Provider\n **I need** the ser...
# 18361  **As a** Service Provider  \n **I need** the s...
# 18362                                                NaN
# 18363  **As a** user\n **I need** the ability to depl...
# 18364  - [ ] database still need to be provisioned\n-...
#
# [18365 rows x 9 columns]

# %%
not_test.labels.value_counts().to_frame()[:50]
# Out:
#                                                     count
# labels
# technical debt                                       4339
# tech debt                                             752
# Technical Debt                                        672
# techdebt                                              641
# tech-debt                                             573
# Technical debt                                        437
# debt                                                  396
# technical-debt                                        279
# Tech Debt                                             208
# enhancement technical debt                             81
# task backlog tech-debt                                 75
# vsa-debt                                               64
# tech_debt                                              58
# T: tech-debt ⚙️                                        53
# Good First Issue Help Wanted Area/Technical Deb...     53
# enhancement tech debt                                  52
# :money_mouth_face: tech debt :warning: P2              48
# design vsa-debt                                        45
# Tech Debt Notify                                       43
# ENTITY techdebt                                        43
# Tech debt                                              42
# :credit_card: technical-debt                           39
# 🔧 Tech Debt                                            38
# tech debt triage                                       37
# kind/tech-debt                                         36
# bug tech-debt                                          35
# techdebt epic                                          34
# enhancement tech-debt                                  34
# Tooling Tech debt                                      32
# type-debt                                              32
# documentation technical debt                           31
# low priority preview tech debt                         30
# Tech Debt dependency update                            30
# good first issue technical debt                        29
# Technology CSP: AWS Technical Debt                     29
# tech-debt no-issue-activity                            29
# type: technical debt                                   29
# Tech Debt Notify QA Review Needed                      29
# bug technical debt                                     29
# documentation techdebt                                 29
# frontend vsa-debt FSR Enhancements PTEMS               28
# type/debt                                              28
# :bank: debt                                            28
# debt team/repo-management                              27
# Technical Debt REST API                                27
# experience tech-debt                                   26
# tech debt Task                                         26
# pipeline tech-debt                                     26
# task tech debt                                         26
# role: dev 🤖 version: 11 package: @carbon/react ...     25

# %%
#Give test a label by number.
# 'Label encoding'. Makes is easier for machine learning models to work with categorical data.
test["label"] = 0
test["class"] = "test"
test.head()
# Out:
#              id         type           created_at  \
# 0  2.700908e+10  IssuesEvent  2023-02-10 14:05:00
# 1  2.733402e+10  IssuesEvent  2023-02-26 00:56:03
# 2  2.733402e+10  IssuesEvent  2023-02-26 00:56:29
# 3  2.733402e+10  IssuesEvent  2023-02-26 00:56:57
# 4  2.414163e+10  IssuesEvent  2022-09-21 15:14:12
#
#                                         repo  \
# 0                       harnettmatt/rankings
# 1                         DataBiosphere/azul
# 2                         DataBiosphere/azul
# 3                         DataBiosphere/azul
# 4  department-of-veterans-affairs/va.gov-cms
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/harnettmatt/rankings  closed
# 1    https://api.github.com/repos/DataBiosphere/azul  closed
# 2    https://api.github.com/repos/DataBiosphere/azul  closed
# 3    https://api.github.com/repos/DataBiosphere/azul  closed
# 4  https://api.github.com/repos/department-of-vet...  closed
#
#                                                title  \
# 0  Make sure integration tests are running with i...
# 1         Cover AnVIL service response in unit tests
# 2  Service `app.repository_controller` should be ...
# 3             Many caches persist between test cases
# 4  Improve friendliness of Behat text pattern mat...
#
#                                              labels  \
# 0                                      testing debt
# 1                  enh demoed debt test orange demo
# 2      bug debt test orange no demo spike:2 service
# 3              enh debt test orange no demo spike:2
# 4  Technical debt Automated testing ⭐️ Sitewide CMS
#
#                                                 body  label class
# 0  Make sure tests are not interfering with each ...      0  test
# 1  https://github.com/DataBiosphere/azul/pull/492...      0  test
# 2  https://github.com/DataBiosphere/azul/blob/350...      0  test
# 3  ~An example is~ https://github.com/DataBiosphe...      0  test
# 4  ## Description\r\n\r\nIn [this commit](https:/...      0  test

# %%
not_test["label"] = 1
not_test["class"] = "not_test" 
not_test.head()
# Out:
#              id         type           created_at  \
# 0  2.729966e+10  IssuesEvent  2023-02-24 00:07:05
# 1  2.729967e+10  IssuesEvent  2023-02-24 00:08:15
# 2  2.729967e+10  IssuesEvent  2023-02-24 00:08:19
# 3  2.729967e+10  IssuesEvent  2023-02-24 00:08:22
# 4  2.729967e+10  IssuesEvent  2023-02-24 00:08:24
#
#                                 repo  \
# 0            kylecorry31/Trail-Sense
# 1  ntlarissa/devops-capstone-project
# 2  ntlarissa/devops-capstone-project
# 3  ntlarissa/devops-capstone-project
# 4  ntlarissa/devops-capstone-project
#
#                                             repo_url  action  \
# 0  https://api.github.com/repos/kylecorry31/Trail...  opened
# 1  https://api.github.com/repos/ntlarissa/devops-...  closed
# 2  https://api.github.com/repos/ntlarissa/devops-...  closed
# 3  https://api.github.com/repos/ntlarissa/devops-...  closed
# 4  https://api.github.com/repos/ntlarissa/devops-...  closed
#
#                                 title          labels  \
# 0             Cache preference values    tech-debt p2
# 1    Update an account in the service  technical debt
# 2  Delete an account from the service  technical debt
# 3    List all accounts in the service  technical debt
# 4  Set up the development environment  technical debt
#
#                                                 body  label     class
# 0  - [ ] Make user prefs a singleton\r\n- [ ] Reg...      1  not_test
# 1                                                NaN      1  not_test
# 2                                                NaN      1  not_test
# 3                                                NaN      1  not_test
# 4                                                NaN      1  not_test

# %%
# Drop duplicates by the content of the body
test = test.drop_duplicates(subset=['title'], keep='last')
test.dropna(inplace=True)
test.reset_index(inplace=True)
test.drop(columns=["index"] , inplace= True)
test["class"].value_counts()
# Out:
# /tmp/ipykernel_1760125/1026750342.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.dropna(inplace=True)
# /tmp/ipykernel_1760125/1026750342.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop(columns=["index"] , inplace= True)
# class
# test    247
# Name: count, dtype: int64

# %%
# Drop duplicates by the content of the body
not_test = not_test.drop_duplicates(subset=['title'], keep='last')
not_test.dropna(inplace=True)
not_test.reset_index(inplace=True)
not_test.drop(columns=["index"] , inplace= True)
not_test["class"].value_counts()
# Out:
# /tmp/ipykernel_1760125/1913840519.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_test.dropna(inplace=True)
# /tmp/ipykernel_1760125/1913840519.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_test.drop(columns=["index"] , inplace= True)
# class
# not_test    10641
# Name: count, dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          247 non-null    float64
#  1   type        247 non-null    object
#  2   created_at  247 non-null    object
#  3   repo        247 non-null    object
#  4   repo_url    247 non-null    object
#  5   action      247 non-null    object
#  6   title       247 non-null    object
#  7   labels      247 non-null    object
#  8   body        247 non-null    object
#  9   label       247 non-null    int64
#  10  class       247 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 21.4+ KB

# %%
label_counts = test["class"].value_counts()
label_counts_nt = not_test["class"].value_counts()
print(label_counts)
not_test_count = label_counts_nt["not_test"]
print(not_test_count)
t_count = label_counts["test"]
t_count
# Out:
# class
# test    247
# Name: count, dtype: int64
# 10641
# 247

# %%
not_test = not_test.sample(frac=t_count/not_test_count, random_state=42, replace= True)
not_test
# Out:
#                 id         type           created_at  \
# 7270  2.810521e+10  IssuesEvent  2023-03-30 23:35:48
# 860   2.342044e+10  IssuesEvent  2022-08-13 16:05:03
# 5390  2.538041e+10  IssuesEvent  2022-11-21 17:05:26
# 5191  2.707687e+10  IssuesEvent  2023-02-14 11:13:35
# 5734  2.453132e+10  IssuesEvent  2022-10-11 16:40:33
# ...            ...          ...                  ...
# 8120  2.349624e+10  IssuesEvent  2022-08-18 01:58:21
# 6616  2.303599e+10  IssuesEvent  2022-07-22 18:48:20
# 5534  2.574650e+10  IssuesEvent  2022-12-08 10:11:20
# 4061  2.716597e+10  IssuesEvent  2023-02-17 15:22:09
# 262   2.599331e+10  IssuesEvent  2022-12-20 09:31:10
#
#                                              repo  \
# 7270     opensearch-project/OpenSearch-Dashboards
# 860                           TASVideos/tasvideos
# 5390                      learningequality/studio
# 5191  privacy-scaling-explorations/zkevm-circuits
# 5734                                    ni/nimble
# ...                                           ...
# 8120    nyu-2022summer-devops-customers/customers
# 6616                          TonyLB/maketheworld
# 5534                             gitpod-io/gitpod
# 4061                                 usds/website
# 262                                nextcloud/mail
#
#                                                repo_url  action  \
# 7270  https://api.github.com/repos/opensearch-projec...  closed
# 860    https://api.github.com/repos/TASVideos/tasvideos  closed
# 5390  https://api.github.com/repos/learningequality/...  opened
# 5191  https://api.github.com/repos/privacy-scaling-e...  opened
# 5734             https://api.github.com/repos/ni/nimble  opened
# ...                                                 ...     ...
# 8120  https://api.github.com/repos/nyu-2022summer-de...  closed
# 6616   https://api.github.com/repos/TonyLB/maketheworld  closed
# 5534      https://api.github.com/repos/gitpod-io/gitpod  closed
# 4061          https://api.github.com/repos/usds/website  closed
# 262         https://api.github.com/repos/nextcloud/mail  closed
#
#                                                   title  \
# 7270                            Fix type errors in i18n
# 860      Move MinimumHoursBeforeJudgment to AppSettings
# 5390  Add prober to alert when the quantity of queue...
# 5191  Handle non-persistance in Log opcode impl in b...
# 5734  Evaluate and extend documentation around writi...
# ...                                                 ...
# 8120  Need to refractor create addresses functionali...
# 6616              Decouple asset lambda with messageBus
# 5534  Remove Helm chart from Werft "publish release"...
# 4061  add the ability to create new pages or section...
# 262                   UrlLinker is not quite maintained
#
#                                                  labels  \
# 7270  good first issue help wanted technical debt ty...
# 860                    Submission System Technical Debt
# 5390   DEV: sysops TAG: tech update / debt DEV: backend
# 5191                      crate-bus-mapping T-tech-debt
# 5734                                   tech debt triage
# ...                                                 ...
# 8120                                     technical debt
# 6616                                      techdebt epic
# 5534                                  aspect: tech-debt
# 4061                                  content tech debt
# 262                        1. to develop technical debt
#
#                                                    body  label     class
# 7270  Task for https://github.com/opensearch-project...      1  not_test
# 860   Currently this is a constant.  Nominally this ...      1  not_test
# 5390  <!--\r\n\r\nNote that anything written between...      1  not_test
# 5191  See: https://github.com/privacy-scaling-explor...      1  not_test
# 5734  ## 🧹 Tech Debt\r\nWe've seen intermittent test...      1  not_test
# ...                                                 ...    ...       ...
# 8120  **As a** developer  \r\n**I need**  to refacto...      1  not_test
# 6616  - #1246 \r\n- #1247 \r\n- #1248 \r\n- #1249 \r...      1  not_test
# 5534  ## Is your feature request related to a proble...      1  not_test
# 4061  "I can edit existing content but I can't creat...      1  not_test
# 262   We should try to remove UrlLinker as a depende...      1  not_test
#
# [247 rows x 11 columns]

# %%
all_debt = pd.concat([test,not_test] , ignore_index = True)
all_debt.tail()
# Out:
#                id         type           created_at  \
# 489  2.349624e+10  IssuesEvent  2022-08-18 01:58:21
# 490  2.303599e+10  IssuesEvent  2022-07-22 18:48:20
# 491  2.574650e+10  IssuesEvent  2022-12-08 10:11:20
# 492  2.716597e+10  IssuesEvent  2023-02-17 15:22:09
# 493  2.599331e+10  IssuesEvent  2022-12-20 09:31:10
#
#                                           repo  \
# 489  nyu-2022summer-devops-customers/customers
# 490                        TonyLB/maketheworld
# 491                           gitpod-io/gitpod
# 492                               usds/website
# 493                             nextcloud/mail
#
#                                               repo_url  action  \
# 489  https://api.github.com/repos/nyu-2022summer-de...  closed
# 490   https://api.github.com/repos/TonyLB/maketheworld  closed
# 491      https://api.github.com/repos/gitpod-io/gitpod  closed
# 492          https://api.github.com/repos/usds/website  closed
# 493        https://api.github.com/repos/nextcloud/mail  closed
#
#                                                  title  \
# 489  Need to refractor create addresses functionali...
# 490              Decouple asset lambda with messageBus
# 491  Remove Helm chart from Werft "publish release"...
# 492  add the ability to create new pages or section...
# 493                  UrlLinker is not quite maintained
#
#                            labels  \
# 489                technical debt
# 490                 techdebt epic
# 491             aspect: tech-debt
# 492             content tech debt
# 493  1. to develop technical debt
#
#                                                   body  label     class
# 489  **As a** developer  \r\n**I need**  to refacto...      1  not_test
# 490  - #1246 \r\n- #1247 \r\n- #1248 \r\n- #1249 \r...      1  not_test
# 491  ## Is your feature request related to a proble...      1  not_test
# 492  "I can edit existing content but I can't creat...      1  not_test
# 493  We should try to remove UrlLinker as a depende...      1  not_test

# %%
# Does this need to be more balanced?
all_debt["label"].value_counts()
# Out:
# label
# 0    247
# 1    247
# Name: count, dtype: int64

# %%
print(all_debt["title"][0])
print(all_debt["body"][0])
# Out:
# Make sure integration tests are running with isolated datasets
# Make sure tests are not interfering with each other when creating and reading data

# %%
# Copy content of body to a new col named text
all_debt["text"] = all_debt["title"] + all_debt["body"]
all_debt.tail()
# Out:
#                id         type           created_at  \
# 489  2.349624e+10  IssuesEvent  2022-08-18 01:58:21
# 490  2.303599e+10  IssuesEvent  2022-07-22 18:48:20
# 491  2.574650e+10  IssuesEvent  2022-12-08 10:11:20
# 492  2.716597e+10  IssuesEvent  2023-02-17 15:22:09
# 493  2.599331e+10  IssuesEvent  2022-12-20 09:31:10
#
#                                           repo  \
# 489  nyu-2022summer-devops-customers/customers
# 490                        TonyLB/maketheworld
# 491                           gitpod-io/gitpod
# 492                               usds/website
# 493                             nextcloud/mail
#
#                                               repo_url  action  \
# 489  https://api.github.com/repos/nyu-2022summer-de...  closed
# 490   https://api.github.com/repos/TonyLB/maketheworld  closed
# 491      https://api.github.com/repos/gitpod-io/gitpod  closed
# 492          https://api.github.com/repos/usds/website  closed
# 493        https://api.github.com/repos/nextcloud/mail  closed
#
#                                                  title  \
# 489  Need to refractor create addresses functionali...
# 490              Decouple asset lambda with messageBus
# 491  Remove Helm chart from Werft "publish release"...
# 492  add the ability to create new pages or section...
# 493                  UrlLinker is not quite maintained
#
#                            labels  \
# 489                technical debt
# 490                 techdebt epic
# 491             aspect: tech-debt
# 492             content tech debt
# 493  1. to develop technical debt
#
#                                                   body  label     class  \
# 489  **As a** developer  \r\n**I need**  to refacto...      1  not_test
# 490  - #1246 \r\n- #1247 \r\n- #1248 \r\n- #1249 \r...      1  not_test
# 491  ## Is your feature request related to a proble...      1  not_test
# 492  "I can edit existing content but I can't creat...      1  not_test
# 493  We should try to remove UrlLinker as a depende...      1  not_test
#
#                                                   text
# 489  Need to refractor create addresses functionali...
# 490  Decouple asset lambda with messageBus- #1246 \...
# 491  Remove Helm chart from Werft "publish release"...
# 492  add the ability to create new pages or section...
# 493  UrlLinker is not quite maintainedWe should try...

# %%
all_debt["text"][0]
# Out:
# 'Make sure integration tests are running with isolated datasetsMake sure tests are not interfering with each other when creating and reading data'

# %%
# Make a new dataframe with only text, label and class cols.
all_debt_subset = all_debt[["text" , "label" , "class"]]
all_debt_subset
# Out:
#                                                   text  label     class
# 0    Make sure integration tests are running with i...      0      test
# 1    Cover AnVIL service response in unit testshttp...      0      test
# 2    Service `app.repository_controller` should be ...      0      test
# 3    Many caches persist between test cases~An exam...      0      test
# 4    Improve friendliness of Behat text pattern mat...      0      test
# ..                                                 ...    ...       ...
# 489  Need to refractor create addresses functionali...      1  not_test
# 490  Decouple asset lambda with messageBus- #1246 \...      1  not_test
# 491  Remove Helm chart from Werft "publish release"...      1  not_test
# 492  add the ability to create new pages or section...      1  not_test
# 493  UrlLinker is not quite maintainedWe should try...      1  not_test
#
# [494 rows x 3 columns]

# %%
# Convert to string
all_debt_subset["text_str"] = all_debt_subset['text'].astype(str)
# Out:
# /tmp/ipykernel_1760125/151477105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_debt_subset["text_str"] = all_debt_subset['text'].astype(str)

# %%
all_debt_subset
# Out:
#                                                   text  label     class  \
# 0    Make sure integration tests are running with i...      0      test
# 1    Cover AnVIL service response in unit testshttp...      0      test
# 2    Service `app.repository_controller` should be ...      0      test
# 3    Many caches persist between test cases~An exam...      0      test
# 4    Improve friendliness of Behat text pattern mat...      0      test
# ..                                                 ...    ...       ...
# 489  Need to refractor create addresses functionali...      1  not_test
# 490  Decouple asset lambda with messageBus- #1246 \...      1  not_test
# 491  Remove Helm chart from Werft "publish release"...      1  not_test
# 492  add the ability to create new pages or section...      1  not_test
# 493  UrlLinker is not quite maintainedWe should try...      1  not_test
#
#                                               text_str
# 0    Make sure integration tests are running with i...
# 1    Cover AnVIL service response in unit testshttp...
# 2    Service `app.repository_controller` should be ...
# 3    Many caches persist between test cases~An exam...
# 4    Improve friendliness of Behat text pattern mat...
# ..                                                 ...
# 489  Need to refractor create addresses functionali...
# 490  Decouple asset lambda with messageBus- #1246 \...
# 491  Remove Helm chart from Werft "publish release"...
# 492  add the ability to create new pages or section...
# 493  UrlLinker is not quite maintainedWe should try...
#
# [494 rows x 4 columns]

# %%
all_debt_subset["text_clean"] = all_debt_subset["text_str"].map(preprocess_text)
# Out:
# /tmp/ipykernel_1760125/1249493049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_debt_subset["text_clean"] = all_debt_subset["text_str"].map(preprocess_text)

# %%
# Make a subset with text_clean and label
test_label_text = all_debt_subset[["text_clean" , "label"]]
test_label_text
# Out:
#                                             text_clean  label
# 0    make sure integration tests are running with i...      0
# 1    cover anvil service response in unit testshttp...      0
# 2    service apprepositorycontroller should be cach...      0
# 3    many caches persist between test casesan examp...      0
# 4    improve friendliness of behat text pattern mat...      0
# ..                                                 ...    ...
# 489  need to refractor create addresses functionali...      1
# 490  decouple asset lambda with messagebus 1246 124...      1
# 491  remove helm chart from werft publish release j...      1
# 492  add the ability to create new pages or section...      1
# 493  urllinker is not quite maintainedwe should try...      1
#
# [494 rows x 2 columns]

# %%
# Need to dropna here since cleaning function returns NaN for not english text.
test_label_text.dropna(inplace=True)
test_label_text.reset_index(inplace=True)
test_label_text.drop(columns=["index"] , inplace= True)

test_label_text
# Out:
# /tmp/ipykernel_1760125/1216462133.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_label_text.dropna(inplace=True)
# /tmp/ipykernel_1760125/1216462133.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_label_text.drop(columns=["index"] , inplace= True)
#                                             text_clean  label
# 0    make sure integration tests are running with i...      0
# 1    cover anvil service response in unit testshttp...      0
# 2    service apprepositorycontroller should be cach...      0
# 3    many caches persist between test casesan examp...      0
# 4    improve friendliness of behat text pattern mat...      0
# ..                                                 ...    ...
# 486  need to refractor create addresses functionali...      1
# 487  decouple asset lambda with messagebus 1246 124...      1
# 488  remove helm chart from werft publish release j...      1
# 489  add the ability to create new pages or section...      1
# 490  urllinker is not quite maintainedwe should try...      1
#
# [491 rows x 2 columns]

# %%
# 10% of the data for testing
test_df = test_label_text.sample(frac=0.1, random_state=42)
# Remove test data from test_text
test_label_text = test_label_text.drop(test_df.index)
test_df
# Out:
#                                             text_clean  label
# 452  lintingas a developer i need to follow python ...      1
# 84   allow use of components within wrapper for uni...      0
# 434  migrate componentschannelnotificationsmodalcom...      1
# 474  leverage godot 40 tilemap layersmost of our ti...      1
# 428  review testing code and remove domain filein h...      1
# 312  investigate usage of production groupvars aws ...      1
# 30   create unit tests for resource list and involv...      0
# 220  too much output from waitformarkersnoticed on ...      0
# 484  orders stuck at pending payment when using rev...      1
# 231  improve load time of dashboard home and cluste...      0
# 9    chaindb qsm failure with getisvalid to reprodu...      0
# 124  bug on account existance checking in busmappin...      0
# 422  tech debt cryptography apis description of the...      1
# 204  improve location of large config chunks that s...      0
# 360  plattform stabilizationparent epic 4 all thing...      1
# 70   run probers on azure staging periodicallyrun t...      0
# 430  integ tests should add retry loops for verifyi...      1
# 431  math operands should be cast before assignment...      1
# 364  update readme fileas a usermarket manager i ne...      1
# 211  handledeleteabnormal unit test intermittently ...      0
# 78   port unit tests using the old json abi types t...      0
# 181  tech debt pluginsgoals identify areas of code ...      0
# 424  ruledescriptionsmd can easily become outofdate...      1
# 55   add a gql regression test for symbols subrepo ...      0
# 76   add a demo build for testing purposeseach libr...      0
# 77   matchspec should be valid checklist x i added ...      0
# 154  tech debt fix lgpo module integration tests de...      0
# 265  put the application in dockers containersusing...      1
# 271  convert all http framework headers to lowercas...      1
# 381  matplotlib deprecationsmatplotlib has deprecat...      1
# 101  backport drain provisioning test is flaky due ...      0
# 126  remove sendcommand from servertscurrently ther...      0
# 314  investigate use of cywait in cypress specscywa...      1
# 322  convert all strings 00000 to chain specific va...      1
# 33   seperate the set up process in the gh action f...      0
# 73   on premise gl is sometimes unavailable during ...      0
# 0    make sure integration tests are running with i...      0
# 11   enable packages to provide their own formatter...      0
# 229  integration tests without sudo callsafter main...      0
# 193  cover references panel codemirror side blob wi...      0
# 403  create a schema in flask framework for restful...      1
# 393  task increase unit test coverage of create clu...      1
# 407  convert existing locale strings to use context...      1
# 153  run happy path integration tests only on pushm...      0
# 68   task improve bottlerocket integration tests wh...      0
# 195  can run a widget notebook twice is failing int...      0
# 18   rfe wrangler should provide mock interfaces fo...      0
# 442  various discrepancies between huron and sharep...      1
# 485  use nextjs pages for existing routes descripti...      1

# %%
test_df.label.value_counts().to_frame()[:50]
# Out:
#        count
# label
# 0         27
# 1         22

# %%
test_df = test_df.reset_index(drop=True)
test_label_text = test_label_text.reset_index(drop=True) 
test_label_text
# Out:
#                                             text_clean  label
# 0    cover anvil service response in unit testshttp...      0
# 1    service apprepositorycontroller should be cach...      0
# 2    many caches persist between test casesan examp...      0
# 3    improve friendliness of behat text pattern mat...      0
# 4    run e2e tests for prs is your feature request ...      0
# ..                                                 ...    ...
# 437  need to refractor create addresses functionali...      1
# 438  decouple asset lambda with messagebus 1246 124...      1
# 439  remove helm chart from werft publish release j...      1
# 440  add the ability to create new pages or section...      1
# 441  urllinker is not quite maintainedwe should try...      1
#
# [442 rows x 2 columns]

# %%
# Clean dataset with clean text and labels.
# 0 = Test, 1 = not test
test_label_text.to_csv("clean_test_or_not_test.csv")

# %%
test_df.to_csv("testset_test_or_not_test_clean.csv")

# %%
pri = pd.read_csv("clean_test_or_not_test.csv", index_col=0)
pri
# Out:
#                                             text_clean  label
# 0    cover anvil service response in unit testshttp...      0
# 1    service apprepositorycontroller should be cach...      0
# 2    many caches persist between test casesan examp...      0
# 3    improve friendliness of behat text pattern mat...      0
# 4    run e2e tests for prs is your feature request ...      0
# ..                                                 ...    ...
# 437  need to refractor create addresses functionali...      1
# 438  decouple asset lambda with messagebus 1246 124...      1
# 439  remove helm chart from werft publish release j...      1
# 440  add the ability to create new pages or section...      1
# 441  urllinker is not quite maintainedwe should try...      1
#
# [442 rows x 2 columns]

# %%
test = pd.read_csv("testset_test_or_not_test_clean.csv", index_col=0)
test
# Out:
#                                            text_clean  label
# 0   lintingas a developer i need to follow python ...      1
# 1   allow use of components within wrapper for uni...      0
# 2   migrate componentschannelnotificationsmodalcom...      1
# 3   leverage godot 40 tilemap layersmost of our ti...      1
# 4   review testing code and remove domain filein h...      1
# 5   investigate usage of production groupvars aws ...      1
# 6   create unit tests for resource list and involv...      0
# 7   too much output from waitformarkersnoticed on ...      0
# 8   orders stuck at pending payment when using rev...      1
# 9   improve load time of dashboard home and cluste...      0
# 10  chaindb qsm failure with getisvalid to reprodu...      0
# 11  bug on account existance checking in busmappin...      0
# 12  tech debt cryptography apis description of the...      1
# 13  improve location of large config chunks that s...      0
# 14  plattform stabilizationparent epic 4 all thing...      1
# 15  run probers on azure staging periodicallyrun t...      0
# 16  integ tests should add retry loops for verifyi...      1
# 17  math operands should be cast before assignment...      1
# 18  update readme fileas a usermarket manager i ne...      1
# 19  handledeleteabnormal unit test intermittently ...      0
# 20  port unit tests using the old json abi types t...      0
# 21  tech debt pluginsgoals identify areas of code ...      0
# 22  ruledescriptionsmd can easily become outofdate...      1
# 23  add a gql regression test for symbols subrepo ...      0
# 24  add a demo build for testing purposeseach libr...      0
# 25  matchspec should be valid checklist x i added ...      0
# 26  tech debt fix lgpo module integration tests de...      0
# 27  put the application in dockers containersusing...      1
# 28  convert all http framework headers to lowercas...      1
# 29  matplotlib deprecationsmatplotlib has deprecat...      1
# 30  backport drain provisioning test is flaky due ...      0
# 31  remove sendcommand from servertscurrently ther...      0
# 32  investigate use of cywait in cypress specscywa...      1
# 33  convert all strings 00000 to chain specific va...      1
# 34  seperate the set up process in the gh action f...      0
# 35  on premise gl is sometimes unavailable during ...      0
# 36  make sure integration tests are running with i...      0
# 37  enable packages to provide their own formatter...      0
# 38  integration tests without sudo callsafter main...      0
# 39  cover references panel codemirror side blob wi...      0
# 40  create a schema in flask framework for restful...      1
# 41  task increase unit test coverage of create clu...      1
# 42  convert existing locale strings to use context...      1
# 43  run happy path integration tests only on pushm...      0
# 44  task improve bottlerocket integration tests wh...      0
# 45  can run a widget notebook twice is failing int...      0
# 46  rfe wrangler should provide mock interfaces fo...      0
# 47  various discrepancies between huron and sharep...      1
# 48  use nextjs pages for existing routes descripti...      1
